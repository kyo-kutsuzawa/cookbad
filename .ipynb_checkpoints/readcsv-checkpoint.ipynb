# %%
import pandas as pd
from pandas import Series

# %%
dataframe = pd.read_excel('good.xlsx')

# %%
dataframe
# Out:
#          gram    price REFUSE ENERC_\nKCAL     ENERC    WATER        －  \
# NaN         g  円/100 g      %   kcal/100 g  kJ/100 g  g/100 g  g/100 g
# rice      150    40.38      0          168       703       60      3.5
# asupara    16    189.8      0           24       100       92      2.6
# cabocha  1200     45.1      9           49       205     86.7      1.6
# fish        -     1228      0          272      1138     48.4     32.6
# kyu-ri    100     61.6      2           14        59     95.4        1
# egg        50     48.4     15          151       632     76.1     12.3
#
#          PROTCAA      －.1  FATNLEA ...       ALC   NITRA    THEBRN   CAFFN   \
# NaN      g/100 g  g/100 g  g/100 g ...   g/100 g  g/100 g  g/100 g  g/100 g
# rice        -2.8      0.3     -0.3 ...         -        -        -        -
# asupara     -1.8      0.1     -0.1 ...         -       Tr        -        -
# cabocha      1.1      0.1       Tr ...         -       Tr        -        -
# ...

# %%
type(dataframe)
# Out:
# pandas.core.frame.DataFrame

# %%
rice = dataframe.ix[1]

# %%
type(dataframe.ix[1][0])
# Out:
# int

# %%
rice
# Out:
# gram              150
# price           40.38
# REFUSE              0
# ENERC_\nKCAL      168
# ENERC             703
# WATER              60
# －                 3.5
# PROTCAA          -2.8
# －.1               0.3
# FATNLEA          -0.3
# FASAT            -0.1
# FAMS            -0.07
# FAPU             -0.1
# CHOLE               0
# －.2              36.1
# CHOAVLM         -38.1
# FIBSOL              0
# FIBINS            0.3
#  FIBTG            0.3
# ASH               0.1
# NA                  1
# K                  29
# CA                  3
# MG                  7
# P                  34
# FE                0.1
# ZN                0.6
# CU                0.1
# MN               0.26
# ID                  -
#                 ...
# CARTB               0
# CRYPXB              0
# CARTBEQ             0
# VITA_RAE            0
# VITD                0
# TOCPHA             Tr
# TOCPHB             Tr
# TOCPHG              0
# TOCPHD              0
# VITK                0
# ...

# %%
for k in range(4):
    for i in range(len(rice)):
        if type(dataframe.ix[k][i]) is '-' or ' ':
         dataframe.ix[k][i] = int(dataframe.ix[k][i])
        print(dataframe.ix[k])
# Out:
# gram            0
# price           0
# REFUSE          0
# ENERC_\nKCAL    0
# ENERC           0
# WATER           0
# －               0
# PROTCAA         0
# －.1             0
# FATNLEA         0
# FASAT           0
# FAMS            0
# FAPU            0
# CHOLE           0
# －.2             0
# CHOAVLM         0
# FIBSOL          0
# FIBINS          0
#  FIBTG          0
# ASH             0
# NA              0
# K               0
# CA              0
# MG              0
# P               0
# FE              0
# ZN              0
# CU              0
# MN              0
# ID              0
#                ..
# CARTB           0
# CRYPXB          0
# CARTBEQ         0
# VITA_RAE        0
# VITD            0
# TOCPHA          0
# TOCPHB          0
# TOCPHG          0
# TOCPHD          0
# VITK            0
# THIAHCL         0
# RIBF            0
# NIA             0
# VITB6A          0
# VITB12          0
# FOL             0
# PANTAC          0
# BIOT            0
# VITC            0
# ...

# %%
print(dataframe.ix[i])

# %%
dataframe.columns
# Out:
# Index(['gram', 'price', 'REFUSE', 'ENERC_\nKCAL', 'ENERC', 'WATER', '－',
#        'PROTCAA', '－.1', 'FATNLEA', 'FASAT', 'FAMS', 'FAPU', 'CHOLE', '－.2',
#        'CHOAVLM', 'FIBSOL', 'FIBINS', ' FIBTG', 'ASH', 'NA', 'K', 'CA', 'MG',
#        'P', 'FE', 'ZN', 'CU', 'MN', 'ID', 'SE', 'CR', 'MO', 'RETOL', 'CARTA ',
#        'CARTB ', 'CRYPXB', 'CARTBEQ', 'VITA_RAE', 'VITD', 'TOCPHA', 'TOCPHB ',
#        'TOCPHG', 'TOCPHD', 'VITK', 'THIAHCL ', 'RIBF', 'NIA', 'VITB6A',
#        'VITB12', 'FOL', 'PANTAC', 'BIOT', 'VITC', 'NACL_EQ', 'ALC', 'NITRA ',
#        'THEBRN', 'CAFFN ', 'TAN', 'POLYPHENT', 'ACEAC', '－.3', 'OA', '－.4'],
#       dtype='object')

# %%
colu = dataframe.columns

# %%
type(colu)
# Out:
# pandas.core.indexes.base.Index

# %%
cols = []
for i in range(len(colu)):
    cols.append(colu[i])

# %%
cols
# Out:
# ['gram',
#  'price',
#  'REFUSE',
#  'ENERC_\nKCAL',
#  'ENERC',
#  'WATER',
#  '－',
#  'PROTCAA',
#  '－.1',
#  'FATNLEA',
#  'FASAT',
#  'FAMS',
#  'FAPU',
#  'CHOLE',
#  '－.2',
#  'CHOAVLM',
#  'FIBSOL',
#  'FIBINS',
#  ' FIBTG',
#  'ASH',
#  'NA',
#  'K',
#  'CA',
#  'MG',
#  'P',
#  'FE',
#  'ZN',
#  'CU',
#  'MN',
#  'ID',
#  'SE',
#  'CR',
#  'MO',
#  'RETOL',
#  'CARTA ',
#  'CARTB ',
#  'CRYPXB',
#  'CARTBEQ',
#  'VITA_RAE',
#  'VITD',
#  'TOCPHA',
#  'TOCPHB ',
#  'TOCPHG',
#  'TOCPHD',
#  'VITK',
#  'THIAHCL ',
#  'RIBF',
#  'NIA',
#  'VITB6A',
#  'VITB12',
#  'FOL',
#  'PANTAC',
#  'BIOT',
#  'VITC',
#  'NACL_EQ',
#  'ALC',
#  'NITRA ',
#  'THEBRN',
#  'CAFFN ',
#  'TAN',
#  'POLYPHENT',
#  'ACEAC',
#  '－.3',
#  'OA',
#  '－.4']

# %%
this_cols = [0 for i in range(len(cols))]

# %%
for i in range(len(cols)):
    if i < 2:
        continue
    this_cols[i] += dataframe.ix['egg'][i]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-92-742a7d8fb403> in <module>()
#       2     if i < 2:
#       3         continue
# ----> 4     this_cols[i] += dataframe.ix['egg'][i]
#
# TypeError: unsupported operand type(s) for +=: 'int' and 'str'

# %%
if type(s) is str:
# Out:
# []
