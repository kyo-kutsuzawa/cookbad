# %%
import pandas as pd
from pandas import Series

# %%
dataframe = pd.read_excel('good.xlsx')

# %%
dataframe
# Out:
#          gram    price REFUSE ENERC_\nKCAL     ENERC    WATER        －  \
# NaN         g  円/100 g      %   kcal/100 g  kJ/100 g  g/100 g  g/100 g
# rice      150    40.38      0          168       703       60      3.5
# asupara    16    189.8      0           24       100       92      2.6
# cabocha  1200     45.1      9           49       205     86.7      1.6
# fish        -     1228      0          272      1138     48.4     32.6
# kyu-ri    100     61.6      2           14        59     95.4        1
# egg        50     48.4     15          151       632     76.1     12.3
#
#          PROTCAA      －.1  FATNLEA ...       ALC   NITRA    THEBRN   CAFFN   \
# NaN      g/100 g  g/100 g  g/100 g ...   g/100 g  g/100 g  g/100 g  g/100 g
# rice        -2.8      0.3     -0.3 ...         -        -        -        -
# asupara     -1.8      0.1     -0.1 ...         -       Tr        -        -
# cabocha      1.1      0.1       Tr ...         -       Tr        -        -
# ...

# %%
type(dataframe)
# Out:
# pandas.core.frame.DataFrame

# %%
dataframe[2].ix[2]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\tools\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2392             try:
# -> 2393                 return self._engine.get_loc(key)
#    2394             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas\_libs\index.c:5239)()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas\_libs\index.c:5085)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas\_libs\hashtable.c:20405)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas\_libs\hashtable.c:20359)()
#
# KeyError: 2
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
dataframe.ix[2]
# Out:
# gram               16
# price           189.8
# REFUSE              0
# ENERC_\nKCAL       24
# ENERC             100
# WATER              92
# －                 2.6
# PROTCAA          -1.8
# －.1               0.1
# FATNLEA          -0.1
# FASAT           -0.02
# FAMS                0
# FAPU            -0.05
# CHOLE              Tr
# －.2               4.6
# CHOAVLM          -2.3
# FIBSOL            0.5
# FIBINS            1.6
#  FIBTG            2.1
# ASH               0.7
# NA                  2
# K                 260
# CA                 19
# MG                 12
# P                  61
# FE                0.6
# ZN                0.6
# CU               0.13
# MN               0.23
# ID                  -
#                 ...
# CARTB             360
# CRYPXB              8
# CARTBEQ           370
# VITA_RAE           30
# VITD                0
# TOCPHA            1.6
# TOCPHB              0
# TOCPHG            0.1
# TOCPHD              0
# VITK               46
# ...
